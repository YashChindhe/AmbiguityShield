# %% [markdown]
# # Remember to set the GPU to T4 GPU

# %%
# clone the Ambiguity Shield Repo
# !git clone https://github.com/YashChindhe/AmbiguityShield.git

# %%
# change current folder
# %cd AmbiguityShield

# %%
# Install all requirements
# !pip install -r requirements.txt

# %%
from google.colab.output import eval_js
import os

# %%
# Kill any existing streamlit processes
os.system("pkill -9 streamlit")

# %%
# Get the URL
url = eval_js("google.colab.kernel.proxyPort(8501)")
print(f"CLICK THIS LINK: {url}")

# Run streamlit with all security checks OFF for Colab
# !streamlit run app.py --server.port 8501 --server.enableCORS=false --server.enableXsrfProtection=false
